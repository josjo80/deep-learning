# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:32, 967KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
print(int_words[:10])
print(words[:10])

from collections import Counter

word_counter = Counter(int_words)
total_words = len(int_words)

t = 1e-5

freqs = {word: count/total_words for word, count in word_counter.items()}
p_drop = {word: 1 - np.sqrt(t/freqs[word]) for word in word_counter}
train_words = [word for word in int_words if p_drop[word] < random.random()]


'''
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]
'''
# Out:
# [5241, 3081, 11, 5, 194, 1, 3135, 45, 58, 155]
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# '\nfrom collections import Counter\nimport random\n\nthreshold = 1e-5\nword_counts = Counter(int_words)\ntotal_count = len(int_words)\nfreqs = {word: count/total_count for word, count in word_counts.items()}\np_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}\ntrain_words = [word for word in int_words if p_drop[word] < random.random()]\n'

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,window_size+1)
        
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding], minval = -1, maxval = 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev = 0.1))
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6810 0.3212 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5871 0.3349 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4938 0.3224 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5765 0.3247 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5114 0.3231 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5217 0.3206 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5581 0.3286 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5516 0.3231 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4353 0.3271 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4342 0.3275 sec/batch
# Nearest to between: periphrastic, mole, specialized, imaginations, shemot, chicxulub, nna, disguising,
# Nearest to six: edging, accession, netbios, inhabited, alexei, admiral, ghosts, outdoor,
# Nearest to its: freeh, vita, wavered, stendhal, industrious, epa, guimar, barf,
# Nearest to more: jsf, interventions, brown, illyria, judoka, moral, vase, mace,
# Nearest to seven: crystallized, weinberger, bech, ware, exert, discourse, ntp, commanders,
# Nearest to but: tni, stad, cyg, with, angelos, drink, conceiving, clarified,
# Nearest to i: attached, evaporating, jutsu, bandanese, hail, relieve, installment, nudity,
# Nearest to about: disciples, berra, abarat, cholas, durability, liberation, timelike, porritt,
# Nearest to http: condenser, anglican, allahabad, breathing, energized, pitcairn, singh, builder,
# Nearest to existence: ensure, dysplasia, parishioners, heed, artists, instrumentalists, rattle, vig,
# Nearest to universe: wrist, arrangements, streams, kamigawa, opposed, meteorology, skill, frederik,
# Nearest to square: cations, copyrighted, abandons, micronova, benedict, fetches, dari, forecourt,
# Nearest to resources: script, sulpicius, simo, ichkeria, ambrosian, ma, waitangi, asymptote,
# Nearest to applied: isc, ha, rounds, masturbating, wynne, prefaces, mirabeau, enslavement,
# Nearest to troops: debt, afrique, authorised, infernal, zr, gymnasium, eminence, microcebus,
# Nearest to applications: everitt, fundamentalisms, jahangir, semicolon, vanished, airbus, directorial, sle,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5004 0.3363 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3790 0.3304 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3529 0.3278 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2147 0.3297 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1734 0.3323 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1520 0.3282 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1036 0.3295 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0634 0.3368 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0119 0.3275 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9777 0.3293 sec/batch
# Nearest to between: specialized, various, mole, normalized, periphrastic, geometry, imaginations, do,
# Nearest to six: outdoor, edging, inhabited, accession, ghosts, shoemakers, admiral, born,
# Nearest to its: freeh, corresponding, epa, biodiversity, stendhal, yours, wires, assume,
# Nearest to more: moral, jsf, mace, interventions, undertones, brown, denmark, eventually,
# Nearest to seven: crystallized, model, discourse, weinberger, illinois, christiansen, foremost, britain,
# Nearest to but: tni, with, hong, drink, stad, angelos, cyg, factors,
# Nearest to i: fundamental, attached, twenty, evaporating, hail, jamestown, jutsu, bandanese,
# Nearest to about: disciples, magistrate, abarat, liberation, enlightenment, prefrontal, though, freethinkers,
# Nearest to http: anglican, reference, breathing, condenser, devalued, sold, christopher, allahabad,
# Nearest to existence: ensure, artists, heed, instrumentalists, connection, expansion, parishioners, concerts,
# Nearest to universe: wrist, arrangements, opposed, streams, a, alliance, skill, meteorology,
# Nearest to square: enemy, copyrighted, system, benedict, cations, foundation, tor, micronova,
# Nearest to resources: script, ichkeria, simo, sulpicius, ma, damaging, waitangi, solicitor,
# Nearest to applied: isc, rounds, ha, enslavement, mysterious, masturbating, consistently, routes,
# Nearest to troops: debt, authorised, info, zr, afrique, completed, gymnasium, reasonably,
# Nearest to applications: semicolon, directorial, hampered, everitt, vanished, spring, airbus, jahangir,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9360 0.3312 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9347 0.3331 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8828 0.3284 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8679 0.3261 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8144 0.3288 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8224 0.3310 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7933 0.3293 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7829 0.3275 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7849 0.3346 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7823 0.3309 sec/batch
# Nearest to between: various, mole, periphrastic, specialized, appoints, normalized, imaginations, chicxulub,
# Nearest to six: inhabited, born, outdoor, accession, edging, eleventh, shoemakers, netbios,
# Nearest to its: freeh, corresponding, epa, wavered, assume, biodiversity, report, yours,
# Nearest to more: interventions, jsf, moral, brown, todd, gun, mace, undertones,
# Nearest to seven: weinberger, foremost, nine, christiansen, nationhood, bech, commanders, five,
# Nearest to but: tni, stad, hong, with, clarified, filmed, drink, cyg,
# Nearest to i: fundamental, warming, attached, evaporating, jamestown, twenty, bandanese, relieve,
# Nearest to about: disciples, liberation, durability, magistrate, enlightenment, abarat, bombing, cholas,
# Nearest to http: www, devalued, anglican, reference, condenser, breathing, positioning, limits,
# Nearest to existence: ensure, heed, parishioners, concerts, artists, expansion, connection, instrumentalists,
# Nearest to universe: wrist, arrangements, streams, alliance, opposed, meteorology, skill, claim,
# Nearest to square: enemy, copyrighted, cations, tor, benedict, abandons, foundation, gcc,
# Nearest to resources: script, simo, ichkeria, sulpicius, damaging, ma, cutting, sally,
# Nearest to applied: rounds, ha, isc, masturbating, enslavement, mysterious, promiscuous, distribute,
# Nearest to troops: debt, authorised, zr, gymnasium, info, reasonably, columnists, completed,
# Nearest to applications: vanished, directorial, semicolon, airbus, hampered, teng, windows, everitt,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7908 0.3318 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7539 0.3281 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7173 0.3356 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7100 0.3279 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7504 0.3299 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7215 0.3360 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6863 0.3299 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7146 0.3278 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7047 0.3272 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6875 0.3325 sec/batch
# Nearest to between: periphrastic, various, specialized, mole, appoints, imaginations, shocked, normalized,
# Nearest to six: born, zero, accession, allen, inhabited, nine, shoemakers, one,
# Nearest to its: freeh, oaks, industrious, wavered, epa, assume, andrea, biodiversity,
# Nearest to more: interventions, jsf, moral, judoka, todd, illyria, crest, soundtracks,
# Nearest to seven: five, nine, one, somme, christiansen, bech, nationhood, weinberger,
# Nearest to but: tni, stad, conceiving, clarified, cyg, drink, with, hong,
# Nearest to i: fundamental, jamestown, bandanese, warming, attached, evaporating, twenty, aroostook,
# Nearest to about: disciples, cholas, durability, magistrate, enlightenment, liberation, shortlist, freethinkers,
# Nearest to http: www, devalued, reference, condenser, allahabad, anglican, singh, heels,
# Nearest to existence: heed, ensure, parishioners, dysplasia, starry, artists, concerts, unfettered,
# Nearest to universe: wrist, streams, arrangements, meteorology, alliance, levers, opposed, disparity,
# Nearest to square: cations, abandons, enemy, copyrighted, dkw, shrunk, tor, juridical,
# Nearest to resources: simo, script, ichkeria, sulpicius, damaging, cutting, sally, solves,
# Nearest to applied: rounds, ha, isc, promiscuous, enslavement, masturbating, lui, uneasy,
# Nearest to troops: debt, authorised, infernal, zr, columnists, chinook, gymnasium, knesset,
# Nearest to applications: vanished, directorial, semicolon, windows, mediawiki, airbus, majlis, uncensored,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6593 0.3296 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6754 0.3284 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6203 0.3282 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6328 0.3348 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6234 0.3273 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6595 0.3271 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5765 0.2485 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5357 0.3417 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5205 0.3403 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5054 0.3287 sec/batch
# Nearest to between: mole, periphrastic, various, specialized, imaginations, transferring, explicate, numan,
# Nearest to six: born, zero, one, allen, nine, antonio, buckingham, admiral,
# Nearest to its: freeh, industrious, wavered, assume, epa, enhancing, drought, oaks,
# Nearest to more: interventions, moral, jsf, judoka, illyria, mace, crest, gun,
# Nearest to seven: five, nine, one, actor, somme, nationhood, louis, two,
# Nearest to but: tni, stad, with, cyg, clarified, rhotic, conceiving, drink,
# Nearest to i: fundamental, bandanese, jamestown, evaporating, aroostook, twenty, warming, attached,
# Nearest to about: disciples, durability, cholas, magistrate, freethinkers, enlightenment, forecasts, berra,
# Nearest to http: www, devalued, edu, reference, condenser, allahabad, builder, izz,
# Nearest to existence: heed, ensure, parishioners, dysplasia, starry, quirks, artists, indomitable,
# Nearest to universe: wrist, meteorology, a, streams, arrangements, skill, habits, biting,
# Nearest to square: abandons, cations, dkw, tor, enemy, joual, copyrighted, juridical,
# Nearest to resources: ichkeria, simo, sulpicius, script, cutting, damaging, solves, scanned,
# Nearest to applied: ha, rounds, isc, enslavement, lui, differentiable, fonts, cabbie,
# Nearest to troops: debt, authorised, infernal, zr, chinook, columnists, assassinated, afrique,
# Nearest to applications: windows, directorial, vanished, airbus, semicolon, aquaculture, mediawiki, twos,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4993 0.3386 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4805 0.3295 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4665 0.3290 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5382 0.3409 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4917 0.3318 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4742 0.3290 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4552 0.3294 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4145 0.3350 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4237 0.3303 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4377 0.3282 sec/batch
# Nearest to between: various, mole, periphrastic, explicate, transferring, specialized, discharges, overdue,
# Nearest to six: zero, born, buckingham, allen, shoemakers, edging, one, antonio,
# Nearest to its: freeh, industrious, wavered, erosion, epa, oaks, enhancing, drought,
# Nearest to more: interventions, moral, judoka, illyria, enhanced, jsf, mace, crest,
# Nearest to seven: five, nine, one, nationhood, somme, est, bech, weinberger,
# Nearest to but: tni, with, congreso, ethical, cyg, conceiving, clarified, stad,
# Nearest to i: fundamental, bandanese, jamestown, warming, husserl, funniest, evaporating, let,
# Nearest to about: disciples, durability, cholas, freethinkers, berra, forecasts, shortlist, magistrate,
# Nearest to http: www, edu, devalued, reference, htm, allahabad, izz, builder,
# Nearest to existence: heed, parishioners, starry, dysplasia, ensure, unfettered, counselling, quirks,
# Nearest to universe: wrist, meteorology, a, arrangements, streams, biting, habits, quarks,
# Nearest to square: abandons, cations, joual, dkw, shrunk, juridical, impure, tor,
# Nearest to resources: ichkeria, simo, sulpicius, damaging, script, solves, cutting, scanned,
# Nearest to applied: ha, isc, rounds, differentiable, selim, enslavement, lui, masturbating,
# Nearest to troops: debt, authorised, chinook, zr, assassinated, infernal, forces, columnists,
# Nearest to applications: windows, directorial, basic, aquaculture, twos, harmful, vanished, airbus,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4328 0.3310 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4074 0.3343 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4603 0.3293 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3995 0.3289 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4100 0.3343 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4717 0.3404 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3875 0.3321 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3948 0.3294 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3916 0.3337 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3885 0.3306 sec/batch
# Nearest to between: mole, periphrastic, various, explicate, specialized, overdue, discharges, transferring,
# Nearest to six: zero, one, buckingham, two, edging, born, allen, nine,
# Nearest to its: freeh, industrious, epa, wavered, drought, erosion, oaks, enhancing,
# Nearest to more: interventions, moral, displayed, judoka, enhanced, jsf, crest, mace,
# Nearest to seven: five, nine, one, two, zero, nationhood, somme, est,
# Nearest to but: tni, with, cyg, ethical, conceiving, clarified, wading, steward,
# Nearest to i: fundamental, bandanese, let, jamestown, grasped, cos, husserl, bowyer,
# Nearest to about: disciples, freethinkers, durability, cholas, berra, abarat, magistrate, iceland,
# Nearest to http: www, edu, htm, reference, devalued, allahabad, appendix, izz,
# Nearest to existence: heed, unfettered, starry, ensure, counselling, dysplasia, parishioners, quirks,
# Nearest to universe: wrist, quarks, a, levers, meteorology, arrangements, biting, habits,
# Nearest to square: dkw, cations, impure, joual, abandons, juridical, tor, microfibrils,
# Nearest to resources: ichkeria, sulpicius, damaging, cutting, simo, solves, costs, script,
# Nearest to applied: isc, rounds, ha, differentiable, warehouse, masturbating, promiscuous, selim,
# Nearest to troops: debt, assassinated, authorised, chinook, forces, zr, eminence, columnists,
# Nearest to applications: windows, mediawiki, vanished, basic, twos, programmers, directorial, airbus,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3741 0.3310 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3672 0.3306 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3466 0.3340 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3327 0.3290 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3968 0.3284 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3984 0.3360 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3702 0.3287 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3735 0.3304 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3207 0.3298 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3421 0.3337 sec/batch
# Nearest to between: periphrastic, various, mole, explicate, discharges, overdue, optimizations, convene,
# Nearest to six: zero, one, two, eight, nine, seven, edging, buckingham,
# Nearest to its: freeh, industrious, erosion, oaks, wavered, drought, epa, enhancing,
# Nearest to more: interventions, jsf, moral, judoka, enhanced, displayed, mace, freemen,
# Nearest to seven: five, nine, one, two, zero, est, nationhood, somme,
# Nearest to but: tni, with, cyg, clarified, conceiving, ethical, patrilineal, steward,
# Nearest to i: fundamental, bandanese, let, jamestown, cos, grasped, funniest, evaporating,
# Nearest to about: disciples, cholas, abarat, durability, freethinkers, berra, shortlist, cane,
# Nearest to http: www, edu, htm, reference, devalued, com, listing, appendix,
# Nearest to existence: heed, unfettered, starry, dysplasia, parishioners, counselling, ensure, quirks,
# Nearest to universe: wrist, quarks, meteorology, biting, universes, disparity, levers, a,
# Nearest to square: dkw, joual, impure, abandons, cations, tor, stealthy, shrunk,
# Nearest to resources: damaging, sulpicius, ichkeria, cutting, simo, costs, alembic, solves,
# Nearest to applied: isc, ha, rounds, differentiable, promiscuous, artificial, lui, masturbating,
# Nearest to troops: debt, forces, assassinated, authorised, chinook, germans, eminence, zr,
# Nearest to applications: windows, mediawiki, twos, programmers, basic, vanished, airbus, harmful,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3423 0.3348 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3063 0.3306 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3793 0.3356 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3748 0.3310 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3824 0.3277 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3041 0.3294 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3194 0.3325 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3319 0.3377 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2308 0.3585 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3040 0.3599 sec/batch
# Nearest to between: periphrastic, various, mole, discharges, explicate, optimizations, tripartite, numan,
# Nearest to six: zero, one, eight, two, seven, three, nine, buckingham,
# Nearest to its: freeh, industrious, erosion, epa, wavered, oaks, assume, difficult,
# Nearest to more: interventions, jsf, judoka, mace, phineus, enhanced, displayed, moral,
# Nearest to seven: five, one, nine, zero, two, est, six, four,
# Nearest to but: with, tni, cyg, tolerant, steward, makin, conceiving, opto,
# Nearest to i: fundamental, bandanese, let, cos, jamestown, grasped, funniest, obituary,
# Nearest to about: disciples, durability, cholas, forecasts, freethinkers, shortlist, cane, abarat,
# Nearest to http: www, edu, htm, com, reference, html, devalued, appendix,
# Nearest to existence: unfettered, heed, parishioners, dysplasia, starry, uncertainty, counselling, ensure,
# Nearest to universe: wrist, quarks, meteorology, a, universes, bagwell, habits, tco,
# Nearest to square: joual, dkw, impure, tor, stealthy, cations, abandons, miramax,
# Nearest to resources: damaging, ichkeria, sulpicius, cutting, simo, costs, cascade, alembic,
# Nearest to applied: isc, ha, rounds, differentiable, promiscuous, strides, artificial, fonts,
# Nearest to troops: debt, assassinated, forces, zr, chinook, authorised, germans, eminence,
# Nearest to applications: windows, mediawiki, twos, airbus, programmers, downloaded, addons, vanished,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2946 0.3363 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3121 0.3300 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3335 0.1514 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2396 0.3302 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2203 0.3402 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2067 0.3328 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2213 0.3286 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2097 0.3296 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2283 0.3335 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1780 0.3295 sec/batch
# Nearest to between: periphrastic, various, mole, discharges, explicate, numan, convene, optimizations,
# Nearest to six: zero, one, two, eight, seven, three, edging, buckingham,
# Nearest to its: freeh, wavered, industrious, connecting, erosion, thebans, shadowed, epa,
# Nearest to more: interventions, jsf, mace, enhanced, phineus, judoka, phenolic, fingerprint,
# Nearest to seven: five, nine, one, zero, two, est, bech, six,
# Nearest to but: with, tni, makin, cyg, tolerant, conceiving, patrilineal, steward,
# Nearest to i: fundamental, bandanese, let, funniest, cos, jamestown, fiddler, grasped,
# Nearest to about: forecasts, disciples, berra, cholas, cane, bony, freethinkers, durability,
# Nearest to http: www, edu, htm, reference, html, com, org, appendix,
# Nearest to existence: unfettered, parishioners, heed, uncertainty, ensure, dysplasia, starry, counselling,
# Nearest to universe: wrist, quarks, universes, meteorology, referencing, bagwell, tco, habits,
# Nearest to square: joual, dkw, impure, tor, bitches, miramax, fetches, stealthy,
# Nearest to resources: sulpicius, damaging, ichkeria, simo, cutting, cascade, competitors, alembic,
# Nearest to applied: isc, ha, rounds, strides, ephemeris, speedily, promiscuous, artificial,
# Nearest to troops: forces, zr, debt, chinook, assassinated, eminence, afrique, knesset,
# Nearest to applications: airbus, twos, windows, mediawiki, addons, downloaded, configured, vanished,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2331 0.3338 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2261 0.3327 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2268 0.3349 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1211 0.3310 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1588 0.3310 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1594 0.3349 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1838 0.3305 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2077 0.3356 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1841 0.3345 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1803 0.3354 sec/batch
# Nearest to between: periphrastic, mole, various, discharges, explicate, optimizations, numan, aberration,
# Nearest to six: zero, one, two, eight, three, seven, four, edging,
# Nearest to its: freeh, wavered, assume, industrious, wires, difficult, connecting, thebans,
# Nearest to more: interventions, enhanced, jsf, mace, phineus, judoka, phenolic, displayed,
# Nearest to seven: five, nine, one, zero, two, bech, est, six,
# Nearest to but: with, tni, conceiving, cyg, opto, patrilineal, konami, tolerant,
# Nearest to i: fundamental, cos, let, bandanese, grasped, funniest, obituary, t,
# Nearest to about: abarat, forecasts, disciples, cholas, berra, freethinkers, durability, bony,
# Nearest to http: www, edu, htm, com, html, reference, org, appendix,
# Nearest to existence: unfettered, heed, parishioners, starry, uncertainty, counselling, inferred, ensure,
# Nearest to universe: quarks, wrist, meteorology, particle, universes, astrophysics, bagwell, normed,
# Nearest to square: joual, dkw, miramax, tor, impure, stealthy, bitches, abandons,
# Nearest to resources: damaging, sulpicius, ichkeria, cascade, simo, cutting, vrije, arable,
# Nearest to applied: isc, ha, rounds, artificial, strides, promiscuous, gzip, ephemeris,
# Nearest to troops: forces, zr, chinook, warfare, assassinated, debt, enemy, knesset,
# Nearest to applications: airbus, twos, windows, mediawiki, addons, basic, downloaded, dtd,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1759 0.3327 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2280 0.3316 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1810 25.8430 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1527 0.3922 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2003 0.3802 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1734 0.3747 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2041 0.3510 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1492 0.3329 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1255 0.3388 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1442 0.3342 sec/batch
# Nearest to between: periphrastic, various, mole, explicate, numan, discharges, aberration, optimizations,
# Nearest to six: zero, one, eight, two, seven, three, four, five,
# Nearest to its: freeh, industrious, erosion, wires, assume, difficult, epa, thebans,
# Nearest to more: interventions, mace, jsf, phineus, enhanced, judoka, moral, freemen,
# Nearest to seven: five, one, nine, two, zero, est, six, bech,
# Nearest to but: with, tni, conceiving, makin, miracles, cyg, boineburg, opto,
# Nearest to i: cos, let, bandanese, fundamental, t, grasped, evaporating, find,
# Nearest to about: abarat, disciples, forecasts, cholas, discoveries, enlightenment, freethinkers, berra,
# Nearest to http: www, edu, htm, com, html, reference, org, appendix,
# Nearest to existence: unfettered, uncertainty, heed, parishioners, starry, counselling, inferred, dysplasia,
# Nearest to universe: quarks, particle, meteorology, wrist, universes, astrophysics, bagwell, s,
# Nearest to square: joual, dkw, miramax, tor, stealthy, impure, invariant, fetches,
# Nearest to resources: damaging, sulpicius, cutting, ichkeria, simo, cascade, arable, vrije,
# Nearest to applied: isc, artificial, ha, speedily, strides, rounds, promiscuous, ephemeris,
# Nearest to troops: forces, chinook, zr, warfare, assassinated, enemy, knesset, infantry,
# Nearest to applications: airbus, twos, downloaded, windows, vanished, addons, dtd, mediawiki,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2086 0.3351 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1717 0.3432 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1696 0.3393 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1927 0.3286 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1357 0.3304 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1379 70.3818 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1835 0.3564 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1379 0.3364 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1925 0.3316 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1967 0.3312 sec/batch
# Nearest to between: periphrastic, various, explicate, tripartite, numan, mole, masovia, nna,
# Nearest to six: zero, one, eight, two, seven, three, four, five,
# Nearest to its: industrious, wavered, freeh, assume, erosion, oaks, difficult, thebans,
# Nearest to more: interventions, jsf, mace, phineus, judoka, enhanced, domination, freemen,
# Nearest to seven: five, one, nine, two, zero, six, three, four,
# Nearest to but: with, patrilineal, tni, conceiving, makin, pitted, and, boineburg,
# Nearest to i: bandanese, cos, let, aragon, t, you, don, funniest,
# Nearest to about: abarat, berra, forecasts, freethinkers, cane, enlightenment, iceland, bombing,
# Nearest to http: www, edu, htm, com, html, org, reference, https,
# Nearest to existence: unfettered, uncertainty, heed, starry, parishioners, counselling, tao, inferred,
# Nearest to universe: quarks, universes, meteorology, astrophysics, wrist, particle, bagwell, habits,
# Nearest to square: joual, dkw, carmel, tor, miramax, stealthy, bitches, abandons,
# Nearest to resources: damaging, sulpicius, arable, ichkeria, cutting, simo, cascade, vrije,
# Nearest to applied: isc, ha, strides, speedily, artificial, ephemeris, promiscuous, gzip,
# Nearest to troops: forces, warfare, zr, retreated, chinook, enemy, protostomes, flanks,
# Nearest to applications: airbus, downloaded, twos, addons, windows, vanished, mediawiki, chipsets,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2004 0.3314 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1417 0.3353 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1224 0.3255 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1939 0.3285 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0617 0.3297 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1365 0.3362 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1343 0.3291 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0982 0.3300 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1740 0.0635 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1160 0.3372 sec/batch
# Nearest to between: periphrastic, various, tripartite, discharges, aberration, explicate, masovia, nna,
# Nearest to six: zero, one, eight, two, seven, four, three, five,
# Nearest to its: industrious, freeh, oaks, wavered, difficult, erosion, assume, telecommunication,
# Nearest to more: interventions, phineus, judoka, jsf, enhanced, mace, domination, displayed,
# Nearest to seven: five, one, nine, two, zero, six, four, eight,
# Nearest to but: with, and, boil, tni, tolerant, patrilineal, konami, makin,
# Nearest to i: let, t, cos, you, bandanese, don, then, fundamental,
# Nearest to about: abarat, forecasts, venom, discoveries, bony, etiology, iceland, freethinkers,
# Nearest to http: www, edu, htm, com, html, org, reference, https,
# Nearest to existence: unfettered, uncertainty, heed, starry, parishioners, inferred, dysplasia, provisional,
# Nearest to universe: universes, quarks, astrophysics, meteorology, wrist, particle, habits, referencing,
# Nearest to square: joual, dkw, carmel, stealthy, tor, miramax, bitches, seds,
# Nearest to resources: damaging, arable, cutting, sulpicius, ichkeria, simo, cascade, vrije,
# Nearest to applied: isc, ha, strides, rounds, artificial, speedily, ephemeris, cdf,
# Nearest to troops: forces, zr, enemy, flanks, warfare, campaigns, infantry, chinook,
# Nearest to applications: airbus, windows, twos, downloaded, addons, dtd, vanished, semicolon,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0756 0.3377 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0815 0.3344 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0779 0.3340 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0498 0.4481 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0759 0.3744 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0134 0.3708 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0799 0.3744 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0478 0.3778 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1366 0.3715 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0177 0.3719 sec/batch
# Nearest to between: periphrastic, various, discharges, aberration, masovia, explicate, upwelling, widens,
# Nearest to six: zero, one, two, eight, seven, three, four, five,
# Nearest to its: assume, freeh, industrious, erosion, difficult, thebans, wires, connecting,
# Nearest to more: interventions, mace, phineus, jsf, domination, judoka, enhanced, proportion,
# Nearest to seven: five, one, two, nine, zero, six, four, three,
# Nearest to but: with, and, conceiving, makin, a, konami, boil, pitted,
# Nearest to i: let, t, cos, you, bandanese, don, aragon, find,
# Nearest to about: abarat, bony, forecasts, venom, discoveries, zero, freethinkers, etiology,
# Nearest to http: www, edu, htm, html, com, org, reference, shtml,
# Nearest to existence: unfettered, uncertainty, heed, starry, parishioners, inferred, provisional, uneasy,
# Nearest to universe: quarks, universes, particle, astrophysics, meteorology, wrist, causal, habits,
# Nearest to square: joual, dkw, carmel, tor, fetches, miramax, seds, fixed,
# Nearest to resources: arable, cutting, ichkeria, damaging, simo, sulpicius, hydropower, cascade,
# Nearest to applied: isc, strides, ha, artificial, speedily, cdf, ephemeris, differentiable,
# Nearest to troops: forces, flanks, infantry, enemy, zr, retreated, warfare, chinook,
# Nearest to applications: airbus, twos, addons, dtd, windows, configured, downloaded, mediawiki,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0354 0.3744 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0229 0.3749 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0065 0.3685 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0315 0.3703 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0623 0.3719 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0456 0.3732 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0611 0.3691 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1040 0.3689 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0841 0.3739 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0719 0.3693 sec/batch
# Nearest to between: periphrastic, various, aberration, discharges, explicate, molality, optimizations, mole,
# Nearest to six: zero, one, two, eight, seven, three, five, four,
# Nearest to its: oaks, assume, freeh, wires, erosion, industrious, thebans, epa,
# Nearest to more: interventions, phineus, mace, enhanced, judoka, jsf, subfields, domination,
# Nearest to seven: five, one, nine, two, zero, six, four, three,
# Nearest to but: with, boil, conceiving, simply, and, opto, patrilineal, makin,
# Nearest to i: t, let, cos, you, don, find, bandanese, then,
# Nearest to about: abarat, zero, freethinkers, discoveries, venom, forecasts, nucleosynthesis, disciples,
# Nearest to http: www, htm, edu, com, html, org, shtml, https,
# Nearest to existence: unfettered, uncertainty, heed, starry, inferred, tao, flamingos, theosophy,
# Nearest to universe: universes, quarks, particle, s, meteorology, astrophysics, bagwell, kamigawa,
# Nearest to square: joual, dkw, tor, fetches, invariant, carmel, miramax, seds,
# Nearest to resources: damaging, cutting, sulpicius, arable, hydropower, simo, authoritative, vrije,
# Nearest to applied: isc, strides, cdf, artificial, ha, gzip, ephemeris, speedily,
# Nearest to troops: forces, retreated, infantry, zr, flanks, eminence, warfare, campaigns,
# Nearest to applications: dtd, airbus, twos, addons, vanished, configured, windows, mediawiki,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0600 0.3745 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0795 0.3855 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0725 0.3959 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0604 0.3792 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0494 0.3828 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0591 0.3819 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0877 0.3854 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0633 0.3813 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0824 0.3823 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0885 0.3858 sec/batch
# Nearest to between: periphrastic, various, explicate, masovia, aberration, tripartite, dioceses, predominantly,
# Nearest to six: zero, one, two, eight, seven, five, three, four,
# Nearest to its: assume, oaks, thebans, industrious, freeh, epa, wavered, erosion,
# Nearest to more: interventions, phineus, jsf, enhanced, mace, judoka, engages, indefatigable,
# Nearest to seven: five, one, two, nine, zero, six, four, three,
# Nearest to but: with, and, boil, miracles, makin, simply, pitted, boineburg,
# Nearest to i: t, you, let, don, cos, my, bandanese, me,
# Nearest to about: zero, abarat, discoveries, freethinkers, nucleosynthesis, denominators, forecasts, iceland,
# Nearest to http: www, htm, edu, com, html, org, shtml, https,
# Nearest to existence: unfettered, uncertainty, starry, tao, inferred, parishioners, heed, hutchins,
# Nearest to universe: universes, quarks, particle, astrophysics, meteorology, kamigawa, descendants, wrist,
# Nearest to square: joual, dkw, tor, abandons, nugent, carmel, fetches, miramax,
# Nearest to resources: damaging, cutting, sulpicius, hydropower, authoritative, simo, arable, ichkeria,
# Nearest to applied: isc, strides, cdf, speedily, artificial, gzip, ha, kronecker,
# Nearest to troops: forces, retreated, infantry, enemy, zr, flanks, eminence, warfare,
# Nearest to applications: dtd, airbus, twos, addons, vanished, windows, mediawiki, semicolon,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0307 0.3860 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9911 0.3855 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0281 0.3899 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0617 0.3871 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0691 0.3714 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1330 0.3738 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1350 0.4000 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0399 0.3973 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0443 0.3764 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0728 0.3662 sec/batch
# Nearest to between: periphrastic, various, aberration, explicate, masovia, tripartite, predominantly, do,
# Nearest to six: zero, one, two, eight, seven, five, three, four,
# Nearest to its: assume, thebans, oaks, epa, freeh, industrious, scud, wavered,
# Nearest to more: interventions, phineus, jsf, enhanced, indefatigable, mace, good, proportion,
# Nearest to seven: five, one, two, nine, zero, six, four, three,
# Nearest to but: with, and, boil, makin, simply, conceiving, miracles, pitted,
# Nearest to i: t, you, let, my, me, cos, don, bandanese,
# Nearest to about: zero, abarat, over, redshift, nucleosynthesis, discoveries, venom, iceland,
# Nearest to http: www, htm, edu, com, html, org, https, shtml,
# Nearest to existence: unfettered, uncertainty, starry, hutchins, heed, expansion, sophist, florian,
# Nearest to universe: universes, quarks, particle, astrophysics, meteorology, kamigawa, sentience, causal,
# Nearest to square: joual, dkw, carmel, abandons, fetches, tor, nugent, fastened,
# Nearest to resources: damaging, arable, hydropower, cutting, ichkeria, sulpicius, simo, dumping,
# Nearest to applied: isc, strides, ryle, speedily, benchers, cdf, ha, gzip,
# Nearest to troops: forces, zr, infantry, eminence, retreated, afrique, protostomes, flanks,
# Nearest to applications: dtd, airbus, addons, twos, vanished, windows, downloaded, suse,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9651 0.3759 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0063 0.3696 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0450 0.3690 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0304 0.3701 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0516 0.3739 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0391 0.3399 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0094 0.3698 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9830 0.3718 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0082 0.3829 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9863 0.3837 sec/batch
# Nearest to between: periphrastic, various, aberration, masovia, molality, explicate, discharges, widens,
# Nearest to six: zero, one, two, eight, seven, five, four, three,
# Nearest to its: industrious, wavered, oaks, assume, freeh, difficult, epa, heisman,
# Nearest to more: interventions, enhanced, phineus, jsf, mace, indefatigable, skewed, developed,
# Nearest to seven: one, five, two, nine, zero, six, eight, three,
# Nearest to but: with, and, boil, makin, a, simply, that, be,
# Nearest to i: t, you, let, my, cos, me, bandanese, aragon,
# Nearest to about: zero, over, abarat, venom, bony, forecasts, july, s,
# Nearest to http: www, htm, edu, com, html, org, shtml, https,
# Nearest to existence: uncertainty, unfettered, starry, sophist, hutchins, heed, atheists, attempt,
# Nearest to universe: universes, quarks, particle, kamigawa, managed, referencing, astrophysics, descendants,
# Nearest to square: joual, carmel, dkw, abandons, tor, fastened, fetches, cup,
# Nearest to resources: damaging, sulpicius, arable, cutting, authoritative, hydropower, simo, ichkeria,
# Nearest to applied: isc, strides, ryle, speedily, stiffer, woolley, imager, kulm,
# Nearest to troops: forces, zr, infantry, protostomes, eminence, afrique, retreated, trojans,
# Nearest to applications: dtd, airbus, twos, addons, windows, vanished, suse, downloaded,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9957 0.3788 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9544 0.3735 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0251 0.3741 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9924 0.3693 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0197 0.3697 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0050 0.3749 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9181 0.3693 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9464 0.3719 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9483 0.3700 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9825 0.3758 sec/batch
# Nearest to between: various, aberration, periphrastic, molality, do, explicate, discharges, optimizations,
# Nearest to six: zero, one, two, eight, seven, five, three, four,
# Nearest to its: the, epa, oaks, assume, wavered, industrious, relative, difficult,
# Nearest to more: interventions, enhanced, phineus, skewed, jsf, domination, proportion, developed,
# Nearest to seven: five, one, two, nine, zero, six, eight, three,
# Nearest to but: with, and, boil, makin, a, simply, ruthenian, the,
# Nearest to i: t, cos, you, my, let, me, bandanese, don,
# Nearest to about: zero, over, forecasts, redshift, july, abarat, bony, venom,
# Nearest to http: www, htm, edu, com, org, html, shtml, https,
# Nearest to existence: uncertainty, unfettered, starry, sophist, uneasy, heed, attempt, atheists,
# Nearest to universe: universes, particle, quarks, kamigawa, causal, astrophysics, referencing, managed,
# Nearest to square: joual, carmel, dkw, census, abandons, tor, fastened, fetches,
# Nearest to resources: damaging, hydropower, arable, authoritative, sulpicius, cutting, simo, waitangi,
# Nearest to applied: isc, strides, woolley, cdf, imager, cotta, ryle, stiffer,
# Nearest to troops: forces, infantry, zr, retreated, eminence, protostomes, flanks, trojans,
# Nearest to applications: dtd, airbus, addons, twos, windows, suse, vanished, majlis,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9779 0.3744 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0128 0.3698 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9636 0.3706 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0442 0.3729 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0305 0.3696 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9390 0.3700 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
